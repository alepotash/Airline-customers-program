# %%
import pandas as pd

# %%
Flight_activity = pd.read_csv('Customer Flight Activity.csv')
Loyalty_history = pd.read_csv('Customer Loyalty History.csv')

# %%
Flight_activity = Flight_activity.drop_duplicates()
Flight_activity['records count'] = Flight_activity.groupby('Loyalty Number')['Loyalty Number'].transform('count')

# %%
Flight_activity.to_csv('C_Flight_Activity.csv', index=False)
